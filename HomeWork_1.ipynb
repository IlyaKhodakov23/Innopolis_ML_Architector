# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1.

# %%
[6*1-8*1+3*4]
# Out:
# [10]

# %% [markdown]
# 2.

# %%
[[-3*-8+-7*4,-3*9+-7*-2],[-10*-8+6*4,-10*9+6*-2],[0*-8+-6*4,0*9+-6*-2],[-1*-8+-3*4,-1*9+-3*-2]]
# Out:
# [[-4, -13], [104, -102], [-24, 12], [-4, -3]]

# %% [markdown]
# Function

# %%
def multiply(X,Y):
  for i in range(len(X)):
    # iterate through columns of Y
    for j in range(len(Y[0])):
        # iterate through rows of Y
        for k in range(len(Y)):
            result[i][j] += X[i][k] * Y[k][j]

  for r in result:
    print(r)

# %%
result = [[0]]
# 3x1 matrix
X = [[6,-8,3]]
# 1x3 matrix
Y = [[1,],
    [1,],
    [4,]]
multiply(X,Y)
# Out:
# [10]

# %%
result = [[0,0],[0,0],[0,0],[0,0]]
# 2x4 matrix
X = [[-3,-7],
    [-10,6],
    [0,-6],
     [-1,-3]]
# 2x2 matrix
Y = [[-8,9],
      [4,-2]]
multiply(X,Y)
# Out:
# [-4, -13]
# [104, -102]
# [-24, 12]
# [-4, -3]
